# %% [markdown]
# # 1. What forums/researchers/blogs/conferences do you follow to stay upto date?
#
# - latent.space substack is amazing!!!! swyx Ben Hylak
# - AI Engineering - AI news newsletter + AI Engineering Youtube channel with their workshops! -  best lectures on modern AI research and engineering
# - Simon Willison: https://simonwillison.net/
# - Andrej Karpathy:https://github.com/karpathy/nanoGPT
#   - https://www.youtube.com/@AndrejKarpathy/videos
# - https://www.youtube.com/@automatalearninglab
# - https://www.oreilly.com/radar/
# - OReilly live courses with me!
# - https://www.ai.engineer/
# - https://www.ai.engineer/newsletter

# %% [markdown]
# # What is your todo list when new models release
#
# How to Taste Test a new Model
# I like to start by asking the model extremely short questions. I’ve found that when forced to use less words, I get a much better sense of the model’s personality vs. how it was RLHF’d. Think of them like little temperature checks:
#
# - Summarize all of human knowledge in one word
#
# - Summarize every book ever written in one sentence
#
# - Define what it means to be “moral” in 5 words. Think deeply. Do not hedge.
#
# - What do you want? Answer in 4 words.
#
# - What is your favorite obscure fact in the world? Use as few words as possible.
#
# I often regenerate 3-5x just to get a sense of the spread. Usually there’s 2-3 responses it converges on. Won’t cover the results here, but I think this is useful to try on your own. (Try it on GPT5 vs your favorite model!)
#
# https://simonwillison.net/2025/Aug/7/gpt-5/

# %% [markdown]
# # What is the next big thing you see coming for LLMs?
#
#
# - Progress of LLMs has platoed
# - Learn to work in specs rather than manually do stuff or blindly offload to AI
# - https://www.youtube.com/watch?v=IS_y40zY-hc
# - COntext Engineering - AI Context Literacy

# %% [markdown]
# # Staying current — 2026 sources (GPT-5.5 refresh)
#
# Updated for the GPT-5.5 era. Start with the primary sources, then the curated externals.
#
# ## Primary / official
#
# - **OpenAI API changelog** — the source of truth for new params, models, and deprecations: https://developers.openai.com/api/docs/changelog
# - **OpenAI deprecations page** — what's being sunset (don't teach deprecated features): https://developers.openai.com/api/docs/deprecations
# - **OpenAI Cookbook** — runnable GPT-5.x examples & prompting guides: https://cookbook.openai.com/
# - **OpenAI Traces dashboard** (Agents SDK runs): https://platform.openai.com/traces
#
# ## This repo's research notes (`research/`)
#
# These were compiled for the GPT-5.5 refresh — read them before teaching anything model-specific:
#
# - `research/01-model-variants.md` — current GPT-5.5 model line and variants/pricing
# - `research/02-reasoning-effort-default.md` — `reasoning_effort` default behavior for GPT-5.5
# - `research/03-responses-api-surface.md` — current Responses/Conversations API capabilities
# - `research/04-prompting-guide-deltas.md` — what changed vs. the original GPT-5 prompting guide
# - `research/05-agents-sdk.md` — Agents SDK primitives cheatsheet (agents, tools, handoffs, guardrails, tracing)
# - `research/06-deprecations.md` — deprecated features & sunset dates to avoid
#
# ## External — staying up to date on GPT-5.5
#
# - **Simon Willison's blog** — fast, hands-on takes on each new model release: https://simonwillison.net/
# - **Latent Space** (swyx & Ben Hylak) — podcast + newsletter on frontier models and AI engineering: https://www.latent.space/
# - **AI Engineer** — newsletter, conference talks, and workshops: https://www.ai.engineer/
# - **OpenAI Developers on X / the OpenAI blog** — first signal on new GPT-5.x releases: https://openai.com/news/
# - **Hacker News** — release-day discussion and real-world reports: https://news.ycombinator.com/
#
# > Tip: when GPT-5.5 (or its successors) ships a point update, diff the changelog against `research/` and re-run the "taste test" prompts above to feel the new model's personality.
